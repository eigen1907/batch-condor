# %%
import hist
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
pt1000_current = uproot.open("2025-mu-pt1000-current-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
pt1000_iRPC = uproot.open("2025-mu-pt1000-iRPC-added-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
pt1000_target = uproot.open("2025-mu-pt1000-target-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pt1000_current = uproot.open("2025-mu-pt1000-current-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
#       2 pt1000_iRPC = uproot.open("2025-mu-pt1000-iRPC-added-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
#       3 pt1000_target = uproot.open("2025-mu-pt1000-target-geometry.root:muonAnalyzer/MuonTree").arrays(library='np')
#
# File ~/micromamba/envs/root-py312/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:832, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     829                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
ax = axes.flatten()

var = data['simMuon_pt']
low, high = np.percentile(var, [0.0, 100.0])
bins = 100
h = hist.Hist.new.Regular(bins, low, high).Weight()
h.fill(var)
h.plot(ax=ax[0])
plt.show()

# %%
plt.hist(data['simMuon_pt'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.hist(data['simMuon_pt'])
#       2 plt.show()
#
# File ~/micromamba/envs/root-py312/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
